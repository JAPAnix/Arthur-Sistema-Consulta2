# %% [markdown]
# # 📘 Projeto de Programação Orientada a Objetos – 2º Bimestre
#
# **Nome do Aluno:**
# Arthur Macedo
# **Turma:**
# 2A Ti
# **Tema Escolhido:**
# Consultas Médicas

# %% [markdown]
# Lembre-se esse projeto deve ser personalizado, todas as classe e metodos devem ter uma referencia ao seu nome, exemplo:
#
# class Carro_Fabio:
#
#     def __init__(self, tipo, cor, rodas):
#         self.tipo = tipo
#         self.cor = cor
#         self.rodas = rodas
#
#     def alterar_cor_Fabio(self, nova_cor):
#         self.cor = nova_cor
#         return self.cor

# %% [markdown]
# ## PARTE 1 – Classe Principal e Objetos
#
# **Tarefas:**
# - Definir e criar a classe principal com pelo menos 3 atributos.
# - Implementar o método construtor (`__init__`).
# - Criar pelo menos 2 objetos da classe principal.
# - Implementar um método de exibição de dados.
#
# **Código:**

# %%
# Desenvolva aqui o código da Parte 1
# Classe principal: Consulta_Arthur

class Consulta_Arthur:

    def __init__(self, paciente, medico, data):
        self.paciente = paciente
        self.medico = medico
        self.data = data

    # Método para exibir os dados da consulta
    def exibir_dados_Arthur(self):
        print(f"Paciente: {self.paciente}")
        print(f"Médico: {self.medico}")
        print(f"Data: {self.data}")

# Criando dois objetos da classe principal
consulta1 = Consulta_Arthur("João Silva", "Dr. Carlos", "2025-06-10")
consulta2 = Consulta_Arthur("Maria Souza", "Dra. Ana", "2025-06-15")

# Exibindo os dados das consultas
consulta1.exibir_dados_Arthur()
consulta2.exibir_dados_Arthur()
# Out:
# Paciente: João Silva
# Médico: Dr. Carlos
# Data: 2025-06-10
# Paciente: Maria Souza
# Médico: Dra. Ana
# Data: 2025-06-15

# %% [markdown]
# ## PARTE 2 – Métodos e Herança
#
# **Tarefas:**
# - Criar pelo menos 2 métodos de ação para a classe principal.
# - Criar uma subclasse herdando da classe principal.
# - Adicionar pelo menos 1 novo atributo e 1 novo método exclusivo na subclasse.
# - Utilizar `super()` no construtor da subclasse.
#
# **Código:**

# %%
# Desenvolva aqui o código da Parte 2
# Adicionando métodos de ação na classe principal

class Consulta_Arthur:

    def __init__(self, paciente, medico, data):
        self.paciente = paciente
        self.medico = medico
        self.data = data

    def exibir_dados_Arthur(self):
        print(f"Paciente: {self.paciente}")
        print(f"Médico: {self.medico}")
        print(f"Data: {self.data}")

    # Método para alterar a data da consulta
    def alterar_data_Arthur(self, nova_data):
        self.data = nova_data
        print(f"Data alterada para: {self.data}")

    # Método para alterar o médico
    def alterar_medico_Arthur(self, novo_medico):
        self.medico = novo_medico
        print(f"Médico alterado para: {self.medico}")

# Subclasse: ConsultaEspecializada_Arthur

class ConsultaEspecializada_Arthur(Consulta_Arthur):

    def __init__(self, paciente, medico, data, especialidade):
        super().__init__(paciente, medico, data)  # Chamando o construtor da superclasse
        self.especialidade = especialidade  # Novo atributo exclusivo da subclasse

    # Novo método exclusivo da subclasse
    def exibir_especialidade_Arthur(self):
        print(f"Especialidade: {self.especialidade}")

# Criando objeto da subclasse
consulta_especial = ConsultaEspecializada_Arthur("Pedro Lima", "Dra. Beatriz", "2025-06-20", "Cardiologia")

# Exibindo dados e especialidade
consulta_especial.exibir_dados_Arthur()
consulta_especial.exibir_especialidade_Arthur()
# Out:
# Paciente: Pedro Lima
# Médico: Dra. Beatriz
# Data: 2025-06-20
# Especialidade: Cardiologia

# %% [markdown]
# ## PARTE 3 – Encapsulamento e Abstração
#
# **Tarefas:**
# - Tornar pelo menos 1 atributo da classe principal privado (`__atributo`).
# - Criar métodos `get` e `set` para o atributo privado.
# - Implementar um método que contenha lógica interna (ex: cálculo, verificação).
#
# **Código:**

# %%
# Desenvolva aqui o código da Parte 3

class Consulta_Arthur:

    def __init__(self, paciente, medico, data):
        self.__paciente = paciente  # Atributo privado
        self.medico = medico
        self.data = data

    # Método get para paciente
    def get_paciente_Arthur(self):
        return self.__paciente

    # Método set para paciente
    def set_paciente_Arthur(self, novo_paciente):
        self.__paciente = novo_paciente
        print(f"Paciente alterado para: {self.__paciente}")

    def exibir_dados_Arthur(self):
        print(f"Paciente: {self.__paciente}")
        print(f"Médico: {self.medico}")
        print(f"Data: {self.data}")

    # Método com lógica interna: verificar se a data é futura
    def verificar_data_Arthur(self):
        from datetime import datetime
        data_consulta = datetime.strptime(self.data, "%Y-%m-%d")
        hoje = datetime.today()
        if data_consulta > hoje:
            print("A consulta está agendada para o futuro.")
        else:
            print("A data da consulta já passou ou é hoje.")

# Teste
consulta_privada = Consulta_Arthur("Clara Mendes", "Dr. Gustavo", "2025-07-01")
consulta_privada.exibir_dados_Arthur()
consulta_privada.verificar_data_Arthur()
# Out:
# Paciente: Clara Mendes
# Médico: Dr. Gustavo
# Data: 2025-07-01
# A consulta está agendada para o futuro.

# %% [markdown]
# ## PARTE 4 – Polimorfismo e Banco de Dados
#
# **Tarefas:**
# - Implementar polimorfismo: sobrescrever um método na subclasse.
# - Integrar o sistema com banco de dados (MySQL ou SQLite).
# - Implementar inserção (INSERT), consulta (SELECT) e exclusão (DELETE) de registros no banco de dados.
#
# **Código:**

# %%
# Desenvolva aqui o código da Parte 4

# %% [markdown]
# ## PARTE 5 – Projeto Final e Organização
#
# **Tarefas:**
# - Consolidar todas as partes do projeto em um único script organizado.
# - Comentar o código explicando cada parte.
# - Testar todas as funcionalidades.
#
# **Código:**

# %%
# Desenvolva aqui o código da Parte 5
import mysql.connector
from datetime import datetime

# Classe principal
class Consulta_Arthur:

    def __init__(self, paciente, medico, data):
        self.__paciente = paciente
        self.medico = medico
        self.data = data

    # Getter e Setter para paciente
    def get_paciente_Arthur(self):
        return self.__paciente

    def set_paciente_Arthur(self, novo_paciente):
        self.__paciente = novo_paciente

    # Exibir dados
    def exibir_dados_Arthur(self):
        print(f"Paciente: {self.__paciente}")
        print(f"Médico: {self.medico}")
        print(f"Data: {self.data}")

    # Verificar se a data é futura
    def verificar_data_Arthur(self):
        data_consulta = datetime.strptime(self.data, "%Y-%m-%d")
        hoje = datetime.today()
        if data_consulta > hoje:
            print("A consulta está agendada para o futuro.")
        else:
            print("A data da consulta já passou ou é hoje.")

    # Salvar no MySQL
    def salvar_no_banco_Arthur(self, conexao):
        cursor = conexao.cursor()
        sql = "INSERT INTO consultas (paciente, medico, data) VALUES (%s, %s, %s)"
        valores = (self.__paciente, self.medico, self.data)
        cursor.execute(sql, valores)
        conexao.commit()
        print("Consulta salva no banco de dados MySQL.")

# Subclasse com polimorfismo
class ConsultaEspecializada_Arthur(Consulta_Arthur):

    def __init__(self, paciente, medico, data, especialidade):
        super().__init__(paciente, medico, data)
        self.especialidade = especialidade

    # Sobrescrevendo o método de exibição
    def exibir_dados_Arthur(self):
        print(f"Paciente: {self.get_paciente_Arthur()}")
        print(f"Médico: {self.medico} - Especialidade: {self.especialidade}")
        print(f"Data: {self.data}")

# Função para conectar ao banco de dados MySQL
def conectar_banco_Arthur():
    conexao = mysql.connector.connect(
        host="localhost",
        user="root",         # Substitua pelo seu usuário
        password="sua_senha",# Substitua pela sua senha
        database="consultas_arthur"
    )
    return conexao

# Função para consultar registros
def consultar_banco_Arthur(conexao):
    cursor = conexao.cursor()
    cursor.execute("SELECT * FROM consultas")
    resultados = cursor.fetchall()
    print("\nConsultas registradas no banco de dados:")
    for linha in resultados:
        print(linha)

# Função para deletar um registro
def deletar_consulta_Arthur(conexao, paciente):
    cursor = conexao.cursor()
    sql = "DELETE FROM consultas WHERE paciente = %s"
    cursor.execute(sql, (paciente,))
    conexao.commit()
    print(f"Consulta de {paciente} deletada com sucesso.")

# =======================
# Testando todas as funções
# =======================

# Conectando ao banco
conexao = conectar_banco_Arthur()

# Criando objetos
consulta1 = Consulta_Arthur("Ana Clara", "Dr. Pedro", "2025-09-15")
consulta2 = ConsultaEspecializada_Arthur("Carlos Eduardo", "Dra. Sofia", "2025-10-20", "Ortopedia")

# Exibindo e verificando
consulta1.exibir_dados_Arthur()
consulta1.verificar_data_Arthur()

consulta2.exibir_dados_Arthur()

# Salvando no banco
consulta1.salvar_no_banco_Arthur(conexao)
consulta2.salvar_no_banco_Arthur(conexao)

# Consultando registros
consultar_banco_Arthur(conexao)

# Deletando um registro
deletar_consulta_Arthur(conexao, "Ana Clara")

# Consultando após deletar
consultar_banco_Arthur(conexao)

# Fechando conexão
conexao.close()
